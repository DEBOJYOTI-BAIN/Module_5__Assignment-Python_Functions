# %% [markdown]
# #Theory Questions and Answsers
#
#  Note: For each theory Question, give at least one example.
#  1. What is the difference between a function and a method in Python?
#   - Function: A block of code defined using def or lambda that performs a specific task. It is not tied to any object.
#   -Method: A function associated with an object (usually defined in a class). It is called on that object using dot (.) notation.
#
#           def greet(name):
#               return "Hello, " + name #function
#           name = "Alice"
#           print(name.upper()) #method
#
#           O/P: ALICE
#
#  2. Explain the concept of function arguments and parameters in Python.
#   - Parameters: Variables listed in the function definition.
#   - Arguments: Actual values passed to the function when it is called.
#                 def add(a, b):  # a and b are parameters
#                     return a + b
#                 print(add(5, 3))  # 5 and 3 are arguments
#
#                 O/P: 8
#
#  3. What are the different ways to define and call a function in Python?
#   - It sends back a result from the function to the caller.
#   - It also ends the function execution.
#
#                           def square(x):
#                               return x * x
#
#                           print(square(4))
#
#
#                           square = lambda x: x * x
#                           print(square(5))
#
#                           O/P:
#                           16
#                           25
#  4. What is the purpose of the `return` statement in a Python function?
#   - It sends back a result from the function to the caller.
#   - It also ends the function execution.
#                         def multiply(x, y):
#                             return x * y
#
#                         result = multiply(3, 4)
#                         print(result)  # Output: 12
#
#  5. What are iterators in Python and how do they differ from iterables?
#   - Iterable: An object that can return an iterator using iter() (e.g., list, tuple).
#   - Iterator: An object with __next__() and __iter__() methods.
#                     lst = [1, 2, 3]        # iterable
#                     it = iter(lst)         # iterator
#
#                     print(next(it))        # Output: 1
#                     print(next(it))        # Output: 2
#  6. Explain the concept of generators in Python and how they are defined.
#   - Generators are functions that use yield to return an iterator, producing values one at a time.
#                         def countdown(n):
#                             while n > 0:
#                                 yield n
#                                 n -= 1
#
#                         for number in countdown(3):
#                             print(number)
#
#                         O/P:
#                         3
#                         2
#                         1
#
#  7. What are the advantages of using generators over regular functions?
#   - Memory-efficient: They don’t store all values in memory.
#   - Lazy evaluation: Values are generated only when needed.
#
#                   def gen():
#                       for i in range(1000000):
#                           yield i
#
#                   # Using the generator
#                   for val in gen():
#                       print(val)
#                       if val == 5:  # stopping early for demonstration
#                           break
#
#
#                       O/P:
#                       0
#                       1
#                       2
#                       3
#                       4
#                       5
#  8. What is a lambda function in Python and when is it typically used?
#   - A lambda function is a small anonymous function defined with the lambda keyword.
#                           square = lambda x: x ** 2
#                           print(square(6))  # Output: 36
#
#  9. Explain the purpose and usage of the `map()` function in Python.
#   - Applies a function to every item in an iterable and returns a map object (can be converted to list).
#
#                       nums = [1, 2, 3]
#                       squared = list(map(lambda x: x**2, nums))
#                       print(squared)  # Output: [1, 4, 9]
#
#  10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#  list:[47,11,42,13];
#   - The map(), filter(), and reduce() functions are part of Python’s functional programming tools used to process data in iterables. The map() function takes a function and an iterable as inputs and applies the function to each element of the iterable, returning a new transformed iterable (typically converted to a list or another iterable type). For example, using map() with a lambda to square a list [1, 2, 3] will produce [1, 4, 9].
#
#   - In contrast, the filter() function also takes a function and an iterable, but instead of transforming elements, it filters out the elements that do not satisfy the given condition. It returns a new iterable containing only those elements for which the function returns True. For instance, filtering even numbers from [1, 2, 3, 4] will result in [2, 4].
#
#   - The reduce() function, found in the functools module, is slightly different. It applies a specified function cumulatively to the elements of the iterable, reducing it to a single value. For example, using reduce() with a lambda that adds numbers on the list [1, 2, 3, 4] would proceed as: 1 + 2 = 3, then 3 + 3 = 6, then 6 + 4 = 10, ultimately returning 10.
#
#   - In summary, map() transforms each element, filter() selects specific elements, and reduce() combines elements into one result.

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list: [47,11,42,13];
# (Attach paper image for this answer) in doc or colab notebook.

# %% [markdown]
# #Practical Questions and Answers

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b574e2f5-7b37-44b8-99c3-16469e0aa751" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b574e2f5-7b37-44b8-99c3-16469e0aa751">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from IPython.display import Image
Image("Module_5__Assignment___Python_Functions Question 11 (2).jpg")

# %%
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
def sum_even_numbers(lst):
    return sum(num for num in lst if num % 2 == 0)


print(sum_even_numbers([1, 2, 3, 4, 5, 6]))
# Out:
# 12

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string.
def reverse_string(s):
    return s[::-1]


print(reverse_string("hello"))
# Out:
# olleh

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

def square_list(lst):
    return [x**2 for x in lst]


print(square_list([1, 2, 3, 4]))
# Out:
# [1, 4, 9, 16]

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5)+1):
        if n % i == 0:
            return False
    return True


print(is_prime(29))
print(is_prime(100))
# Out:
# True
# False

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

class Fibonacci:
    def __init__(self, max_terms):
        self.max_terms = max_terms
        self.count = 0
        self.a, self.b = 0, 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        value = self.a
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return value

for num in Fibonacci(7):
    print(num, end=' ')
# Out:
# 0 1 1 2 3 5 8

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

def powers_of_two(n):
    for i in range(n + 1):
        yield 2 ** i


for power in powers_of_two(4):
    print(power, end=' ')
# Out:
# 1 2 4 8 16

# %%
 # 7. Implement a generator function that reads a file line by line and yields each line as a string.

import io

def read_file_lines(file_obj):
    for line in file_obj:
        yield line.strip()


sample_text = """Line 1: Hello
Line 2: Python
Line 3: Generator"""
fake_file = io.StringIO(sample_text)


for line in read_file_lines(fake_file):
    print(line)
# Out:
# Line 1: Hello
# Line 2: Python
# Line 3: Generator

# %%
 #8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
tuples = [(1, 3), (2, 1), (4, 2)]
sorted_list = sorted(tuples, key=lambda x: x[1])


print(sorted_list)
# Out:
# [(2, 1), (4, 2), (1, 3)]

# %%
 #9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
celsius = [0, 20, 40, 100]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))


print(fahrenheit)
# Out:
# [32.0, 68.0, 104.0, 212.0]

# %%
 #10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

def remove_vowels(s):
    return ''.join(filter(lambda ch: ch.lower() not in 'aeiou', s))


print(remove_vowels("Hello World"))
# Out:
# Hll Wrld

# %%
# 11.  Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.


orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]
result_basic = list(map(
    lambda x: (x[0], round(x[2] * x[3] + (10 if x[2] * x[3] < 100 else 0), 2)),
    orders
))

print(result_basic)


result_lambda_map = list(map(
    lambda order: (order[0], round(order[2]*order[3] + (10 if order[2]*order[3] < 100 else 0), 2)),
    orders
))

print(result_lambda_map)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]
# [(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]
